# %%
import pandas as pd

# Remplacez "path/to/your/excel/file.xlsx" par le chemin de votre fichier Excel
file_path = "movie_synopsis.xlsx"

# Obtenez la liste des noms de feuilles
excel_sheets = pd.ExcelFile(file_path).sheet_names

# Chargez les données depuis la première feuille spécifiée en utilisant pandas
# Si vous avez plusieurs feuilles, accédez à la feuille souhaitée du dictionnaire
excel_data = pd.read_excel(file_path, sheet_name=excel_sheets[0])

# Affichez les données
pd.set_option('display.max_colwidth', None)
excel_data.head()


#Extract  
#Actor / char Name [1]
#Location  [2]
# Out:
#   mpst_full_data                                     Unnamed: 1  \
# 0        imdb_id                                          title
# 1      tt0057603                        I tre volti della paura
# 2      tt1733125  Dungeons & Dragons: The Book of Vile Darkness
# 3      tt0033045                     The Shop Around the Corner
# 4      tt0113862                             Mr. Holland's Opus
#
# ...
